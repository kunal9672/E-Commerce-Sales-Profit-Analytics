# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Clean_Ecommerce.csv")

# %%
df.head()
# Out:
#   Order_ID  Order_Date Customer_Name              Email       Phone     City  \
# 0  ORD1002  30-06-2025          Neha   neha82@gmail.com  9829008196    Delhi
# 1  ORD1003  03-02-2025         Rohit  rohit45@gmail.com  9280491167     Pune
# 2  ORD1004  06-05-2025          Amit    amit6@gmail.com  9943310925   Jaipur
# 3  ORD1007  10-02-2025         Rahul  rahul82@gmail.com  9517780193   Mumbai
# 4  ORD1008  17-02-2025         Rahul  rahul71@gmail.com  9789375429  Lucknow
#
#          State Product     Category  Qty  ...  Discount  Payment_Mode  \
# 0        Delhi   Chair    Furniture    4  ...         0           UPI
# 1  Maharashtra   Watch      Fashion    5  ...         0          Card
# 2    Rajasthan   Mouse  Electronics    3  ...         0           COD
# 3  Maharashtra   Mouse  Electronics    3  ...         0        Wallet
# 4           Up   Mouse  Electronics    4  ...         0          Card
#
#   Order_Status Delivery_Date    Sales  Net_Amount  Profit     Month    Year  \
# 0      Pending    07-03-2025   7996.0      7996.0  1599.2      June  2025.0
# 1      Pending    02-09-2025  24995.0     24995.0  4999.0  February  2025.0
# 2     Returned    05-08-2025   5997.0      5997.0  1199.4       May  2025.0
# 3    Cancelled    10-02-2025   1497.0      1497.0   299.4  February  2025.0
# 4     Returned    17-02-2025  39996.0     39996.0  7999.2  February  2025.0
#
#    Weekday
# 0   Monday
# 1   Monday
# 2  Tuesday
# 3   Monday
# 4   Monday
#
# [5 rows x 21 columns]

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:12345@localhost/ecommerce')

# %%
df.to_sql(
    name='orders',
    con=engine,
    if_exists='replace',
    index=False
)
# Out:
# 380

# %%
df.shape
# Out:
# (380, 21)

# %%
df
# Out:
#     Order_ID  Order_Date Customer_Name              Email       Phone  \
# 0    ORD1002  30-06-2025          Neha   neha82@gmail.com  9829008196
# 1    ORD1003  03-02-2025         Rohit  rohit45@gmail.com  9280491167
# 2    ORD1004  06-05-2025          Amit    amit6@gmail.com  9943310925
# 3    ORD1007  10-02-2025         Rahul  rahul82@gmail.com  9517780193
# 4    ORD1008  17-02-2025         Rahul  rahul71@gmail.com  9789375429
# ..       ...         ...           ...                ...         ...
# 375  ORD1608  17-02-2025         Rahul  rahul71@gmail.com  9789375429
# 376  ORD1609         NaN         Rahul  rahul99@gmail.com  9552649559
# 377  ORD1610  10-04-2025         Rohit  rohit96@gmail.com  9700116928
# 378  ORD1611  11-01-2025          Neha   neha22@gmail.com  9580304152
# 379  ORD1612  03-03-2025         Vikas  vikas46@gmail.com  9551158398
#
#         City        State Product     Category  Qty  ...  Discount  \
# 0      Delhi        Delhi   Chair    Furniture    4  ...         0
# 1       Pune  Maharashtra   Watch      Fashion    5  ...         0
# 2     Jaipur    Rajasthan   Mouse  Electronics    3  ...         0
# 3     Mumbai  Maharashtra   Mouse  Electronics    3  ...         0
# 4    Lucknow           Up   Mouse  Electronics    4  ...         0
# ..       ...          ...     ...          ...  ...  ...       ...
# 375  Lucknow           Up   Mouse  Electronics    4  ...         0
# 376   Mumbai  Maharashtra  Bottle         Home    2  ...         0
# 377   Jaipur    Rajasthan   Mouse  Electronics    1  ...         0
# 378   Jaipur    Rajasthan   Chair    Furniture    3  ...         0
# 379   Jaipur    Rajasthan   Shoes      Fashion    3  ...         0
#
#      Payment_Mode Order_Status Delivery_Date    Sales  Net_Amount  Profit  \
# 0             UPI      Pending    07-03-2025   7996.0      7996.0  1599.2
# 1            Card      Pending    02-09-2025  24995.0     24995.0  4999.0
# 2             COD     Returned    05-08-2025   5997.0      5997.0  1199.4
# 3          Wallet    Cancelled    10-02-2025   1497.0      1497.0   299.4
# 4            Card     Returned    17-02-2025  39996.0     39996.0  7999.2
# ..            ...          ...           ...      ...         ...     ...
# 375          Card     Returned    17-02-2025  39996.0     39996.0  7999.2
# 376        Wallet      Pending           NaN   2998.0      2998.0   599.6
# 377    NetBanking    Delivered    10-04-2025      NaN         NaN     NaN
# 378           COD      Pending    11-01-2025   2997.0      2997.0   599.4
# 379           COD    Cancelled    03-09-2025   2997.0      2997.0   599.4
#
#         Month    Year   Weekday
# 0        June  2025.0    Monday
# 1    February  2025.0    Monday
# 2         May  2025.0   Tuesday
# 3    February  2025.0    Monday
# 4    February  2025.0    Monday
# ..        ...     ...       ...
# 375  February  2025.0    Monday
# 376       NaN     NaN       NaN
# 377     April  2025.0  Thursday
# 378   January  2025.0  Saturday
# 379     March  2025.0    Monday
#
# [380 rows x 21 columns]
